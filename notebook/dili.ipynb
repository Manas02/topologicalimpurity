# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# from plotnine import ggplot, aes, geom_bar, geom_line, facet_wrap, theme_minimal, labs

# %%
df = pd.read_csv('../benchmark/tdc_one_adme_results_tree.csv')

# %%
# Calculate differences in metrics
df['Accuracy_Diff'] = df['Topological_Decision_Tree_Accuracy'] - df['Decision_Tree_Accuracy']
df['Precision_Diff'] = df['Topological_Decision_Tree_Precision'] - df['Decision_Tree_Precision']
df['Recall_Diff'] = df['Topological_Decision_Tree_Recall'] - df['Decision_Tree_Recall']
df['Balanced_Accuracy_Diff'] = df['Topological_Decision_Tree_Balanced_Accuracy'] - df['Decision_Tree_Balanced_Accuracy']
df['F1_Score_Diff'] = df['Topological_Decision_Tree_F1_Score'] - df['Decision_Tree_F1_Score']
df['AUC_ROC_Diff'] = df['Topological_Decision_Tree_AUC_ROC'] - df['Decision_Tree_AUC_ROC']

# List of metric differences to plot
metrics = ['Accuracy_Diff', 'Precision_Diff', 'Recall_Diff', 'Balanced_Accuracy_Diff', 'F1_Score_Diff', 'AUC_ROC_Diff']

# Create a single figure with multiple subplots
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(18, 15))
fig.suptitle('Heatmaps of Metric Differences between Topological Decision Tree and Decision Tree', fontsize=16)

# Group the data by the relevant columns and calculate mean differences
grouped = df.groupby(['Dataset', 'Sim_threshold', 'Molecular_network_Fingeprint', 'Model_Fingeprint']).mean().reset_index()

# Iterate over metrics and axes
for i, metric in enumerate(metrics):
    # Determine row and column index
    row = i // 2
    col = i % 2
    
    # Create a pivot table for the heatmap
    pivot_table = grouped.pivot_table(index='Model_Fingeprint', columns=['Dataset', 'Sim_threshold', 'Molecular_network_Fingeprint'], values=metric)
    
    # Plot the heatmap on the corresponding subplot
    sns.heatmap(pivot_table, annot=True, cmap='coolwarm', ax=axes[row, col])
    axes[row, col].set_title(f'Heatmap of {metric}')
    axes[row, col].set_xlabel('Dataset, Sim_threshold, Molecular_network_Fingeprint')
    axes[row, col].set_ylabel('Model_Fingeprint')

# Adjust layout for better viewing
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# Define metrics to melt
metrics = [
    "Topological_Decision_Tree_Accuracy", "Decision_Tree_Accuracy",
    "Topological_Decision_Tree_Precision", "Decision_Tree_Precision",
    "Topological_Decision_Tree_Recall", "Decision_Tree_Recall",
    "Topological_Decision_Tree_Balanced_Accuracy", "Decision_Tree_Balanced_Accuracy",
    "Topological_Decision_Tree_F1_Score", "Decision_Tree_F1_Score",
    "Topological_Decision_Tree_AUC_ROC", "Decision_Tree_AUC_ROC"
]

# Melt the DataFrame to create a DataFrame with metric types and values
df_melted = df.melt(id_vars=['Dataset', 'Sim_threshold', 'Molecular_network_Fingeprint', 'Model_Fingeprint'],
                    value_vars=metrics,
                    var_name='metric_type',
                    value_name='value')

# Extract the decision tree type (Topological or Decision) and metric name from the metric type
df_melted['decision_tree_type'] = df_melted['metric_type'].apply(lambda x: 'Topological' if 'Topological' in x else 'Decision')
df_melted['metric_name'] = df_melted['metric_type'].apply(lambda x: x.split('_', 2)[2])  # Splitting and keeping only metric name

# Set up the plot
plt.figure(figsize=(12, 8))

# Create a violin plot comparing the distributions of each metric for "Topological Decision Tree" and "Decision Tree"
ax = sns.violinplot(data=df_melted, x='metric_name', y='value', hue='decision_tree_type', split=True, inner='quartile')

# Set y-tick labels rotation (optional, you can adjust the angle as needed)
ax.set_yticklabels(ax.get_yticklabels(), rotation=45)

# Set x-tick labels to remove underscores and rotate for readability
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Set title and labels
plt.title('Comparison of Metrics between Topological and Decision Tree Models')
plt.xlabel('Metric Name')
plt.ylabel('Metric Value')

# Show the plot
plt.show()
# Out:
# /var/folders/nj/v2qpgqmx5v95v_p1dzfj62yr0000gn/T/ipykernel_64004/2507420753.py:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(), rotation=45)
# /var/folders/nj/v2qpgqmx5v95v_p1dzfj62yr0000gn/T/ipykernel_64004/2507420753.py:31: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %% [markdown]
# # Visualising Topological impurity reduction in practice

# %%
import os
from joblib import load
os.chdir('../benchmark')

# %%
clf = load("./dili.joblib")

# %%
clf
# Out:
# {'split_feature': 650,
#  'split_value': 0,
#  'left': {'split_feature': 97,
#   'split_value': 0,
#   'left': {'split_feature': 1855,
#    'split_value': 0,
#    'left': {'split_feature': 1946,
#     'split_value': 0,
#     'left': {'split_feature': 932,
#      'split_value': 0,
#      'left': {'split_feature': 73,
#       'split_value': 0,
#       'left': {'split_feature': 165,
#        'split_value': 0,
#        'left': {'split_feature': 571,
#         'split_value': 0,
#         'left': {'split_feature': 68,
#          'split_value': 0,
#          'left': {'split_feature': 307,
#           'split_value': 0,
#           'left': {'split_feature': 229,
#            'split_value': 0,
#            'left': {'split_feature': 552,
#             'split_value': 0,
#             'left': {'split_feature': 20,
#              'split_value': 0,
#              'left': {'split_feature': 141,
#               'split_value': 0,
#               'left': {'split_feature': 145,
#                'split_value': 0,
#                'left': {'leaf': True,
#                 'class': 0,
#                 'topological_impurity': 0.012984764542936287,
#                 'P_active': 0.013157894736842105},
#                'right': {'leaf': True,
#                 'class': 1,
#                 'topological_impurity': 0.0,
#                 'P_active': 1.0},
#                'topological_impurity': 0.0252993759487266,
#                'P_active': 0.025974025974025976},
#               'right': {'leaf': True,
#                'class': 1,
#                'topological_impurity': 0.0,
#                'P_active': 1.0},
#               'topological_impurity': 0.03698224852071006,
#               'P_active': 0.038461538461538464},
#              'right': {'leaf': True,
#               'class': 1,
#               'topological_impurity': 0.0,
#               'P_active': 1.0},
#              'topological_impurity': 0.048069219676333916,
#              'P_active': 0.05063291139240506},
#             'right': {'leaf': True,
#              'class': 1,
#              'topological_impurity': 0.0,
#              'P_active': 1.0},
#             'topological_impurity': 0.058795103092783504,
#             'P_active': 0.0625},
#            'right': {'leaf': True,
#             'class': 1,
#             'topological_impurity': 0.0,
#             'P_active': 1.0},
#            'topological_impurity': 0.06905688032019844,
#            'P_active': 0.07407407407407407},
#           'right': {'leaf': True,
#            'class': 1,
#            'topological_impurity': 0.0,
#            'P_active': 1.0},
#           'topological_impurity': 0.0791408175405796,
#           'P_active': 0.08536585365853659},
#          'right': {'leaf': True,
#           'class': 1,
#           'topological_impurity': 0.0,
#           'P_active': 1.0},
#          'topological_impurity': 0.09055611258566541,
#          'P_active': 0.0963855421686747},
#         'right': {'leaf': True,
#          'class': 1,
#          'topological_impurity': 0.0,
#          'P_active': 1.0},
#         'topological_impurity': 0.10269283432222728,
#         'P_active': 0.10714285714285714},
#        'right': {'leaf': True,
#         'class': 1,
#         'topological_impurity': 0.0,
#         'P_active': 1.0},
#        'topological_impurity': 0.11555188724167485,
#        'P_active': 0.11764705882352941},
#       'right': {'leaf': True,
#        'class': 1,
#        'topological_impurity': 0.0,
#        'P_active': 1.0},
#       'topological_impurity': 0.12900627836433326,
#       'P_active': 0.12790697674418605},
#      'right': {'split_feature': 13,
#       'split_value': 0,
#       'left': {'leaf': True,
#        'class': 1,
#        'topological_impurity': 0.0,
#        'P_active': 1.0},
#       'right': {'leaf': True,
#        'class': 0,
#        'topological_impurity': 0.0,
#        'P_active': 0.0},
#       'topological_impurity': 0.1875,
#       'P_active': 0.75},
#      'topological_impurity': 0.15282651072124756,
#      'P_active': 0.15555555555555556},
#     'right': {'leaf': True,
#      'class': 1,
#      'topological_impurity': 0.0,
#      'P_active': 1.0},
#     'topological_impurity': 0.17055689778918956,
#     'P_active': 0.17391304347826086},
#    'right': {'split_feature': 1028,
#     'split_value': 0,
#     'left': {'split_feature': 1939,
#      'split_value': 0,
#      'left': {'leaf': True,
#       'class': 1,
#       'topological_impurity': 0.0,
#       'P_active': 1.0},
#      'right': {'split_feature': 449,
#       'split_value': 0,
#       'left': {'leaf': True,
#        'class': 0,
#        'topological_impurity': 0.0,
#        'P_active': 0.0},
#       'right': {'leaf': True,
#        'class': 1,
#        'topological_impurity': 0.0,
#        'P_active': 1.0},
#       'topological_impurity': 0.2222222222222222,
#       'P_active': 0.3333333333333333},
#      'topological_impurity': 0.21251475796930344,
#      'P_active': 0.8181818181818182},
#     'right': {'leaf': True,
#      'class': 0,
#      'topological_impurity': 0.0,
#      'P_active': 0.0},
#     'topological_impurity': 0.3507692307692308,
#     'P_active': 0.6},
#    'topological_impurity': 0.2190741307976508,
#    'P_active': 0.2336448598130841},
#   'right': {'leaf': True,
#    'class': 1,
#    'topological_impurity': 0.0,
#    'P_active': 1.0},
#   'topological_impurity': 0.23973960283654744,
#   'P_active': 0.26785714285714285},
#  'right': {'split_feature': 1873,
#   'split_value': 0,
#   'left': {'split_feature': 941,
#    'split_value': 0,
#    'left': {'split_feature': 437,
#     'split_value': 0,
#     'left': {'split_feature': 132,
#      'split_value': 0,
#      'left': {'split_feature': 20,
#       'split_value': 0,
#       'left': {'split_feature': 91,
#        'split_value': 0,
#        'left': {'split_feature': 113,
#         'split_value': 0,
#         'left': {'split_feature': 162,
#          'split_value': 0,
#          'left': {'split_feature': 488,
#           'split_value': 0,
#           'left': {'leaf': True,
#            'class': 0,
#            'topological_impurity': 0.0,
#            'P_active': 0.0},
#           'right': {'leaf': True,
#            'class': 1,
#            'topological_impurity': 0.0,
#            'P_active': 1.0},
#           'topological_impurity': 0.023242630385487528,
#           'P_active': 0.023809523809523808},
#          'right': {'leaf': True,
#           'class': 1,
#           'topological_impurity': 0.0,
#           'P_active': 1.0},
#          'topological_impurity': 0.04434829637641969,
#          'P_active': 0.046511627906976744},
#         'right': {'leaf': True,
#          'class': 1,
#          'topological_impurity': 0.0,
#          'P_active': 1.0},
#         'topological_impurity': 0.06353305785123967,
#         'P_active': 0.06818181818181818},
#        'right': {'leaf': True,
#         'class': 1,
#         'topological_impurity': 0.0,
#         'P_active': 1.0},
#        'topological_impurity': 0.082012814502266,
#        'P_active': 0.08888888888888889},
#       'right': {'leaf': True,
#        'class': 1,
#        'topological_impurity': 0.0,
#        'P_active': 1.0},
#       'topological_impurity': 0.10046908912693411,
#       'P_active': 0.10869565217391304},
#      'right': {'leaf': True,
#       'class': 1,
#       'topological_impurity': 0.0,
#       'P_active': 1.0},
#      'topological_impurity': 0.13730567392676768,
#      'P_active': 0.14583333333333334},
#     'right': {'leaf': True,
#      'class': 1,
#      'topological_impurity': 0.0,
#      'P_active': 1.0},
#     'topological_impurity': 0.1722,
#     'P_active': 0.18},
#    'right': {'split_feature': 486,
#     'split_value': 0,
#     'left': {'leaf': True,
#      'class': 1,
#      'topological_impurity': 0.0,
#      'P_active': 1.0},
#     'right': {'leaf': True,
#      'class': 0,
#      'topological_impurity': 0.0,
#      'P_active': 0.0},
#     'topological_impurity': 0.22000000000000003,
#     'P_active': 0.8},
#    'topological_impurity': 0.23166005075811805,
#    'P_active': 0.23636363636363636},
#   'right': {'split_feature': 1162,
#    'split_value': 0,
#    'left': {'split_feature': 1911,
#     'split_value': 0,
#     'left': {'split_feature': 458,
#      'split_value': 0,
#      'left': {'split_feature': 632,
#       'split_value': 0,
#       'left': {'split_feature': 658,
#        'split_value': 0,
#        'left': {'split_feature': 590,
#         'split_value': 0,
#         'left': {'split_feature': 414,
#          'split_value': 0,
#          'left': {'split_feature': 589,
#           'split_value': 0,
#           'left': {'split_feature': 27,
#            'split_value': 0,
#            'left': {'split_feature': 1408,
#             'split_value': 0,
#             'left': {'split_feature': 592,
#              'split_value': 0,
#              'left': {'split_feature': 369,
#               'split_value': 0,
#               'left': {'split_feature': 1342,
#                'split_value': 0,
#                'left': {'leaf': True,
#                 'class': 1,
#                 'topological_impurity': 0.09379072630163916,
#                 'P_active': 0.900709219858156},
#                'right': {'leaf': True,
#                 'class': 0,
#                 'topological_impurity': 0.2222222222222222,
#                 'P_active': 0.3333333333333333},
#                'topological_impurity': 0.10561571228823204,
#                'P_active': 0.8888888888888888},
#               'right': {'leaf': True,
#                'class': 0,
#                'topological_impurity': 0.0,
#                'P_active': 0.0},
#               'topological_impurity': 0.11525476394116484,
#               'P_active': 0.8827586206896552},
#              'right': {'leaf': True,
#               'class': 0,
#               'topological_impurity': 0.0,
#               'P_active': 0.0},
#              'topological_impurity': 0.1254992485099207,
#              'P_active': 0.8707482993197279},
#             'right': {'leaf': True,
#              'class': 0,
#              'topological_impurity': 0.0,
#              'P_active': 0.0},
#             'topological_impurity': 0.1365574287378873,
#             'P_active': 0.8590604026845637},
#            'right': {'leaf': True,
#             'class': 0,
#             'topological_impurity': 0.0,
#             'P_active': 0.0},
#            'topological_impurity': 0.1473551996360724,
#            'P_active': 0.847682119205298},
#           'right': {'split_feature': 427,
#            'split_value': 0,
#            'left': {'leaf': True,
#             'class': 0,
#             'topological_impurity': 0.0,
#             'P_active': 0.0},
#            'right': {'leaf': True,
#             'class': 1,
#             'topological_impurity': 0.0,
#             'P_active': 1.0},
#            'topological_impurity': 0.24,
#            'P_active': 0.4},
#           'topological_impurity': 0.162479809572388,
#           'P_active': 0.8333333333333334},
#          'right': {'leaf': True,
#           'class': 0,
#           'topological_impurity': 0.0,
#           'P_active': 0.0},
#          'topological_impurity': 0.17445505575295783,
#          'P_active': 0.8227848101265823},
#         'right': {'split_feature': 80,
#          'split_value': 0,
#          'left': {'leaf': True,
#           'class': 1,
#           'topological_impurity': 0.0,
#           'P_active': 1.0},
#          'right': {'leaf': True,
#           'class': 0,
#           'topological_impurity': 0.0,
#           'P_active': 0.0},
#          'topological_impurity': 0.16000000000000003,
#          'P_active': 0.2},
#         'topological_impurity': 0.19034567660542093,
#         'P_active': 0.803680981595092},
#        'right': {'leaf': True,
#         'class': 0,
#         'topological_impurity': 0.0,
#         'P_active': 0.0},
#        'topological_impurity': 0.20302546752786443,
#        'P_active': 0.7891566265060241},
#       'right': {'leaf': True,
#        'class': 0,
#        'topological_impurity': 0.0,
#        'P_active': 0.0},
#       'topological_impurity': 0.21710849024690917,
#       'P_active': 0.7751479289940828},
#      'right': {'leaf': True,
#       'class': 0,
#       'topological_impurity': 0.0,
#       'P_active': 0.0},
#      'topological_impurity': 0.23516637265028142,
#      'P_active': 0.7572254335260116},
#     'right': {'split_feature': 1,
#      'split_value': 0,
#      'left': {'split_feature': 890,
#       'split_value': 0,
#       'left': {'split_feature': 62,
#        'split_value': 0,
#        'left': {'leaf': True,
#         'class': 1,
#         'topological_impurity': 0.0,
#         'P_active': 1.0},
#        'right': {'leaf': True,
#         'class': 0,
#         'topological_impurity': 0.0,
#         'P_active': 0.0},
#        'topological_impurity': 0.20408163265306123,
#        'P_active': 0.7142857142857143},
#       'right': {'leaf': True,
#        'class': 0,
#        'topological_impurity': 0.0,
#        'P_active': 0.0},
#       'topological_impurity': 0.3174603174603174,
#       'P_active': 0.5555555555555556},
#      'right': {'leaf': True,
#       'class': 0,
#       'topological_impurity': 0.0,
#       'P_active': 0.0},
#      'topological_impurity': 0.31372549019607837,
#      'P_active': 0.3333333333333333},
#     'topological_impurity': 0.2624669414595792,
#     'P_active': 0.723404255319149},
#    'right': {'split_feature': 1722,
#     'split_value': 0,
#     'left': {'split_feature': 456,
#      'split_value': 0,
#      'left': {'split_feature': 29,
#       'split_value': 0,
#       'left': {'split_feature': 105,
#        'split_value': 0,
#        'left': {'leaf': True,
#         'class': 0,
#         'topological_impurity': 0.0,
#         'P_active': 0.0},
#        'right': {'leaf': True,
#         'class': 1,
#         'topological_impurity': 0.0,
#         'P_active': 1.0},
#        'topological_impurity': 0.05916732335172051,
#        'P_active': 0.05555555555555555},
#       'right': {'leaf': True,
#        'class': 1,
#        'topological_impurity': 0.0,
#        'P_active': 1.0},
#       'topological_impurity': 0.11511234225915666,
#       'P_active': 0.10526315789473684},
#      'right': {'leaf': True,
#       'class': 1,
#       'topological_impurity': 0.0,
#       'P_active': 1.0},
#      'topological_impurity': 0.20393533757589055,
#      'P_active': 0.19047619047619047},
#     'right': {'leaf': True,
#      'class': 1,
#      'topological_impurity': 0.0,
#      'P_active': 1.0},
#     'topological_impurity': 0.2989583333333333,
#     'P_active': 0.2916666666666667},
#    'topological_impurity': 0.2978481883316561,
#    'P_active': 0.6745283018867925},
#   'topological_impurity': 0.33528121742091843,
#   'P_active': 0.5842696629213483},
#  'topological_impurity': 0.34194541661210426,
#  'P_active': 0.49076517150395776}

# %% [markdown]
# # Draw the Decision Tree as Image

# %%
import pydot

def plot_binary_decision_tree(tree_dict):
    def add_node_and_edges(graph, node, node_id):
        # Create the current node in the graph
        if 'leaf' in node:
            # Leaf node
            label = f"class: {node['class']}\nimpurity: {node['topological_impurity']:.2f}\nP_active: {node['P_active']}"
            graph.add_node(pydot.Node(node_id, label=label, shape='ellipse', style='filled', fillcolor='lightblue'))
        else:
            # Decision node
            label = f"split_feature: {node['split_feature']}\nsplit_value: {node['split_value']}\nP_active: {node['P_active']}\nimpurity: {node['topological_impurity']:.2f}"
            graph.add_node(pydot.Node(node_id, label=label, shape='box'))

            # Recur on left and right children
            left_node_id = f"{node_id}_left"
            right_node_id = f"{node_id}_right"
            
            # Add left and right child nodes
            add_node_and_edges(graph, node['left'], left_node_id)
            add_node_and_edges(graph, node['right'], right_node_id)
            
            # Add edges from current node to left and right children
            graph.add_edge(pydot.Edge(node_id, left_node_id, label='left'))
            graph.add_edge(pydot.Edge(node_id, right_node_id, label='right'))
    
    # Create a graph
    graph = pydot.Dot(graph_type='digraph')

    # Start adding nodes and edges from the root
    add_node_and_edges(graph, tree_dict, "root")
    
    # Display the graph
    graph.write_png('../dt.png')
    print("Decision tree plotted and saved as 'binary_decision_tree.png'.")

# Plot the binary decision tree
plot_binary_decision_tree(clf)
# Out:
# Decision tree plotted and saved as 'binary_decision_tree.png'.
